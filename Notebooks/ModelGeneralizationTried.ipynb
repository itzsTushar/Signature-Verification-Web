# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/notebooks/tasnimshamim/datasetpreprocessing/__results__.html
# /kaggle/input/notebooks/tasnimshamim/datasetpreprocessing/cedar_224x224.h5
# /kaggle/input/notebooks/tasnimshamim/datasetpreprocessing/__notebook__.ipynb
# /kaggle/input/notebooks/tasnimshamim/datasetpreprocessing/__output__.json
# /kaggle/input/notebooks/tasnimshamim/datasetpreprocessing/cedar_224x224_siamese.h5
# /kaggle/input/notebooks/tasnimshamim/datasetpreprocessing/custom.css
# /kaggle/input/notebooks/tasnimshamim/datasetpreprocessing/__results___files/__results___10_0.png

# %%
from h5py import File
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import permutation, randint, rand
import os
from tensorflow.keras.initializers import RandomNormal, Constant
import tensorflow as tf
from tensorflow.keras.backend import max, mean, sqrt, square, sum

import seaborn as sns
from tensorflow.keras.optimizers import Adam,RMSprop
from keras.models import Model

from tensorflow import keras
from keras.layers import LeakyReLU, Softmax
from keras.layers import Conv2D, Activation, Input,Dropout,Lambda,Flatten, Dense
from keras.layers import Dense, Flatten, Reshape, Activation
from keras.layers import BatchNormalization ,ZeroPadding2D

from keras.layers import MaxPooling2D
from keras.layers import Concatenate
from keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
from keras.layers import Layer, InputSpec
from keras.regularizers import l2
from keras import backend as K
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from tensorflow import one_hot, reshape


from tensorflow.keras.layers import Activation, Add, AvgPool2D, BatchNormalization, Conv2D, Dense, Flatten, Input, MaxPool2D, ZeroPadding2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.initializers import random_uniform, glorot_uniform, constant
from tensorflow.keras.utils import plot_model
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

from h5py import File
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import permutation, randint, rand
from numpy import rint
import os
import seaborn as sns
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import tensorflow as tf

from numpy import expand_dims
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow import keras
from tensorflow import one_hot, reshape
from keras.layers import BatchNormalization
import cv2

# from keras.models import Sequential
from tensorflow.keras.optimizers import Adam,SGD
from tensorflow.keras import Sequential
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.utils import plot_model
# Out:
# 2026-04-25 14:53:45.546790: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1777128825.724822      23 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1777128825.776885      23 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1777128826.175619      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777128826.175663      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777128826.175666      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1777128826.175669      23 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.

# %%
import tensorflow as tf

print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
print(tf.config.list_physical_devices('GPU'))
# Out:
# Num GPUs Available: 2
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
file = '/kaggle/input/notebooks/tasnimshamim/datasetpreprocessing/cedar_224x224_siamese.h5'
print(file)
with File(file, 'r') as hdf:
    S1 = np.array(hdf.get('S1'))
    S2 = np.array(hdf.get('S2'))
    Y = np.array(hdf.get('Y'))
print(S1.shape)
print(S2.shape)
print(Y.shape)
# Out:
# /kaggle/input/notebooks/tasnimshamim/datasetpreprocessing/cedar_224x224_siamese.h5
# (46860, 224, 224, 1)
# (46860, 224, 224, 1)
# (46860, 1)

# %%
ax = sns.countplot(x = Y.reshape(Y.shape[0]))
for p in ax.patches:
   ax.annotate('{:}'.format(p.get_height()), (p.get_x()+0.25, p.get_height()+0.01))

# %%
import sklearn
class_weights = sklearn.utils.class_weight.compute_class_weight(class_weight = "balanced",classes = np.unique(Y),y = Y.reshape(Y.shape[0]))
class_weight_dict = dict(enumerate(class_weights))
class_weight_dict
# Out:
# {0: np.float64(1.5434782608695652), 1: np.float64(0.7395833333333334)}

# %%
Y = Y/1.0

# %%
S1.dtype
# Out:
# dtype('uint8')

# %%
seed=randint(10)
print('seed='+str(seed))
indices = permutation(Y.shape[0])
m = int(0.70 * Y.shape[0])
n = int(0.15 * Y.shape[0])
training_id, validation_id, test_id = indices[:m], indices[m: m + n], indices[m+n:]
S1_train, S1_test, S1_validate = S1[training_id], S1[test_id], S1[validation_id]
S2_train, S2_test, S2_validate = S2[training_id], S2[test_id], S2[validation_id]
Y_train, Y_test, Y_validate = Y[training_id], Y[test_id], Y[validation_id]
print(S1_train.shape)
print(S2_train.shape)
print(Y_train.shape)

del S1,S2,Y
# Out:
# seed=7
# (32802, 224, 224, 1)
# (32802, 224, 224, 1)
# (32802, 1)

# %%
fig = plt.figure(figsize = (16,16))
rows,cols = 4,4
i = 1
while(i in range(1,rows*cols)):
  random_idx = randint(0,len(S1_train))
  if(Y_train[random_idx] == 0):
    Label = "Genuine Pair"
  else:
    Label = "Forged Pair"
  img1 = S1_train[random_idx]
  img2 = S2_train[random_idx]
  fig.add_subplot(rows,cols,i)
  plt.imshow(img1.squeeze(),cmap = "gray");
  plt.axis(False);
  i += 1
  fig.add_subplot(rows,cols,i)
  plt.imshow(img2.squeeze(),cmap = "gray");
  plt.axis(False);
  plt.text(0.5, 0.5, Label, horizontalalignment='center',verticalalignment='center',fontsize=15,fontweight = 1000);
  i += 1

# %%
Y_train[0]
# Out:
# array([1.])

# %%
Y_train.shape
# Out:
# (32802, 1)

# %%
input_shape=(224,224,1)
input_shape
# Out:
# (224, 224, 1)

# %%
def euclidean_distance(vects):
    """Find the Euclidean distance between two vectors.

    Arguments:
        vects: List containing two tensors of same length.

    Returns:
        Tensor containing euclidean distance
        (as floating point value) between vectors.
    """

    x, y = vects
    sum_square = tf.math.reduce_sum(tf.math.square(x - y), axis=1, keepdims=True)
    return tf.math.sqrt(tf.math.maximum(sum_square, tf.keras.backend.epsilon()))

# %%
def constructive_loss(y_true, y_pred):
    '''Contrastive loss from Hadsell-et-al.'06
    http://yann.lecun.com/exdb/publis/pdf/hadsell-chopra-lecun-06.pdf
    '''
    margin = 1
    square_pred = tf.math.square(y_pred)
    margin_square = tf.math.square(tf.math.maximum(margin - (y_pred), 0))
    return tf.math.reduce_mean(
        (1 - y_true) * square_pred + (y_true) * margin_square
    )

# %%
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras import layers
NUM_CLASSES = 2
IMG_SIZE = 224
def build_model(num_classes):
    inputs = layers.Input(shape=(IMG_SIZE, IMG_SIZE, 3))

    data_augmentation = tf.keras.Sequential([
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.05),
        layers.RandomZoom(0.1),
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
        layers.RandomContrast(0.3),
        layers.GaussianNoise(0.05),
    ])

    x = data_augmentation(inputs)

    base_model = EfficientNetB0(include_top=False, input_tensor=x, weights="imagenet")
    base_model.trainable = False

    x = layers.GlobalAveragePooling2D()(base_model.output)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)

    outputs = x

    model = tf.keras.Model(inputs, outputs)
    return model
    # inputs = layers.Input(shape = input_shape)
    # x = inputs
    # model = EfficientNetB0(include_top=False, input_tensor=x, weights = None)

    # # Freeze the pretrained weights
    # model.trainable = False

    # # Rebuild top
    # x = layers.GlobalAveragePooling2D(name="avg_pool")(model.output)
    # x = layers.BatchNormalization()(x)

    # top_dropout_rate = 0.5
    # x = layers.Dropout(top_dropout_rate, name="top_dropout")(x)
    # outputs = layers.Dense(num_classes, activation="sigmoid", name="pred")(x)

    # model = tf.keras.Model(inputs, outputs, name="EfficientNet")
    # return model

# %%
plot_model(build_model(2))
# Out:
# I0000 00:00:1777128871.445605      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1777128871.451321      23 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
with tf.device('/device:GPU:0'):
  inputShape = S1_train.shape[1:]
  f = build_model(num_classes = 2)

# %%
def eucl_dist_output_shape(shapes):
    shape1, shape2 = shapes
    return (shape1[0], 1)

# %%
with tf.device('/device:GPU:0'):
  # network definition
  input_a = Input(shape=(input_shape))
  input_b = Input(shape=(input_shape))

  # because we re-use the same instance `base_network`,
  # the weights of the network
  # will be shared across the two branches
  processed_a = f(input_a)
  processed_b = f(input_b)

  # Compute the Euclidean distance between the two vectors in the latent space
  # https://keras.io/examples/vision/siamese_contrastive/
  merge_layer = Lambda(euclidean_distance)([processed_a, processed_b])

  model = keras.Model(inputs=[input_a, input_b], outputs=merge_layer)

# %%
pred = model([expand_dims(S1_train[0],axis = 0), expand_dims(S2_train[0],axis = 0)])
print(pred.shape)
pred
# Out:
# I0000 00:00:1777128878.635933      23 cuda_dnn.cc:529] Loaded cuDNN version 91002
# (1, 1)
# <tf.Tensor: shape=(1, 1), dtype=float32, numpy=array([[10.133517]], dtype=float32)>

# %%
folder = '/kaggle/working'

# %%
Batch_size = 32
lr = 1e-04
Epochs = 60

# %%
with tf.device('/device:GPU:0'):
    adam = Adam(learning_rate = lr,epsilon = 1e-08)
    model.compile(loss = constructive_loss, optimizer = adam, metrics=['BinaryAccuracy'])

# %%
callbacks = [
    EarlyStopping(patience = 40, verbose = 1),
    ReduceLROnPlateau(factor=0.1, patience = 3, min_lr=0.000001, verbose=1),
    ModelCheckpoint(
    folder + '/Weights/EffiNet-bhsig260-{epoch:03d}.weights.h5',
    verbose=1,
    save_weights_only=True
)
]

# %%
with tf.device('/device:GPU:0'):
    results = model.fit(x = [S1_train, S2_train],
                          y = Y_train,
                        validation_data = ([S1_validate,S2_validate],Y_validate),
                        epochs = Epochs,
                        callbacks = callbacks,
                        batch_size = Batch_size,
                        class_weight = class_weight_dict,
                        steps_per_epoch = S1_train.shape[0]//Batch_size-1,
                        validation_steps = S1_validate.shape[0]//Batch_size-1
                        # To fix Loss Nan on TPU
                        # https://stackoverflow.com/questions/64079759/validation-loss-become-nan-while-training-on-tpu-but-perfectly-ok-on-gpu
                        )
# Out:
# Epoch 1/60
# E0000 00:00:1777128905.236698      23 meta_optimizer.cc:967] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/functional_4_1/functional_3_1/block2b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - BinaryAccuracy: 0.6723 - loss: 1398.3365
# Epoch 1: saving model to /kaggle/working/Weights/EffiNet-bhsig260-001.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 196s 172ms/step - BinaryAccuracy: 0.6723 - loss: 1398.2738 - val_BinaryAccuracy: 0.6839 - val_loss: 195.9689 - learning_rate: 1.0000e-04
# Epoch 2/60
#    2/1024 ━━━━━━━━━━━━━━━━━━━━ 53s 52ms/step - BinaryAccuracy: 0.8180 - loss: 570.0865
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Epoch 2: saving model to /kaggle/working/Weights/EffiNet-bhsig260-002.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.8235 - loss: 552.8450 - val_BinaryAccuracy: 0.6839 - val_loss: 198.5042 - learning_rate: 1.0000e-04
# Epoch 3/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.6728 - loss: 1169.7766
# Epoch 3: saving model to /kaggle/working/Weights/EffiNet-bhsig260-003.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.6728 - loss: 1169.7257 - val_BinaryAccuracy: 0.6839 - val_loss: 167.1695 - learning_rate: 1.0000e-04
# Epoch 4/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:23 140ms/step - BinaryAccuracy: 0.6562 - loss: 1023.2975
# Epoch 4: saving model to /kaggle/working/Weights/EffiNet-bhsig260-004.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.6471 - loss: 1029.6569 - val_BinaryAccuracy: 0.6839 - val_loss: 168.2892 - learning_rate: 1.0000e-04
# Epoch 5/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.6700 - loss: 986.7373
# Epoch 5: saving model to /kaggle/working/Weights/EffiNet-bhsig260-005.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.6700 - loss: 986.6811 - val_BinaryAccuracy: 0.6839 - val_loss: 137.2184 - learning_rate: 1.0000e-04
# Epoch 6/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:22 140ms/step - BinaryAccuracy: 0.6562 - loss: 890.7927
# Epoch 6: saving model to /kaggle/working/Weights/EffiNet-bhsig260-006.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.6177 - loss: 967.0864 - val_BinaryAccuracy: 0.6839 - val_loss: 139.0177 - learning_rate: 1.0000e-04
# Epoch 7/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.6686 - loss: 812.7689
# Epoch 7: saving model to /kaggle/working/Weights/EffiNet-bhsig260-007.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.6686 - loss: 812.7161 - val_BinaryAccuracy: 0.6839 - val_loss: 114.4239 - learning_rate: 1.0000e-04
# Epoch 8/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:20 138ms/step - BinaryAccuracy: 0.6250 - loss: 760.2255
# Epoch 8: saving model to /kaggle/working/Weights/EffiNet-bhsig260-008.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.6470 - loss: 715.5500 - val_BinaryAccuracy: 0.6839 - val_loss: 115.6867 - learning_rate: 1.0000e-04
# Epoch 9/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.6758 - loss: 644.9716
# Epoch 9: saving model to /kaggle/working/Weights/EffiNet-bhsig260-009.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.6758 - loss: 644.9413 - val_BinaryAccuracy: 0.6839 - val_loss: 91.5236 - learning_rate: 1.0000e-04
# Epoch 10/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:25 142ms/step - BinaryAccuracy: 0.6250 - loss: 658.7394
# Epoch 10: saving model to /kaggle/working/Weights/EffiNet-bhsig260-010.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.6470 - loss: 620.0278 - val_BinaryAccuracy: 0.6839 - val_loss: 92.6010 - learning_rate: 1.0000e-04
# Epoch 11/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.6742 - loss: 513.2597
# Epoch 11: saving model to /kaggle/working/Weights/EffiNet-bhsig260-011.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.6742 - loss: 513.2314 - val_BinaryAccuracy: 0.6839 - val_loss: 71.8689 - learning_rate: 1.0000e-04
# Epoch 12/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:23 140ms/step - BinaryAccuracy: 0.8125 - loss: 195.2315
# Epoch 12: saving model to /kaggle/working/Weights/EffiNet-bhsig260-012.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.8235 - loss: 183.7585 - val_BinaryAccuracy: 0.6839 - val_loss: 71.9513 - learning_rate: 1.0000e-04
# Epoch 13/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.6698 - loss: 402.6380
# Epoch 13: saving model to /kaggle/working/Weights/EffiNet-bhsig260-013.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.6698 - loss: 402.6085 - val_BinaryAccuracy: 0.6839 - val_loss: 55.6442 - learning_rate: 1.0000e-04
# Epoch 14/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:22 139ms/step - BinaryAccuracy: 0.6250 - loss: 337.8661
# Epoch 14: saving model to /kaggle/working/Weights/EffiNet-bhsig260-014.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.6177 - loss: 336.2502 - val_BinaryAccuracy: 0.6839 - val_loss: 56.2245 - learning_rate: 1.0000e-04
# Epoch 15/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.6724 - loss: 299.6515
# Epoch 15: saving model to /kaggle/working/Weights/EffiNet-bhsig260-015.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 171ms/step - BinaryAccuracy: 0.6724 - loss: 299.6300 - val_BinaryAccuracy: 0.6839 - val_loss: 40.5934 - learning_rate: 1.0000e-04
# Epoch 16/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:24 142ms/step - BinaryAccuracy: 0.7188 - loss: 214.5602
# Epoch 16: saving model to /kaggle/working/Weights/EffiNet-bhsig260-016.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.7353 - loss: 201.9514 - val_BinaryAccuracy: 0.6839 - val_loss: 41.1198 - learning_rate: 1.0000e-04
# Epoch 17/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.6729 - loss: 217.6362
# Epoch 17: saving model to /kaggle/working/Weights/EffiNet-bhsig260-017.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.6729 - loss: 217.6184 - val_BinaryAccuracy: 0.6839 - val_loss: 29.2956 - learning_rate: 1.0000e-04
# Epoch 18/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:22 140ms/step - BinaryAccuracy: 0.7500 - loss: 123.7927
# Epoch 18: saving model to /kaggle/working/Weights/EffiNet-bhsig260-018.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.7059 - loss: 142.3436 - val_BinaryAccuracy: 0.6839 - val_loss: 29.4928 - learning_rate: 1.0000e-04
# Epoch 19/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.6727 - loss: 150.5728
# Epoch 19: saving model to /kaggle/working/Weights/EffiNet-bhsig260-019.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 175s 171ms/step - BinaryAccuracy: 0.6727 - loss: 150.5580 - val_BinaryAccuracy: 0.6839 - val_loss: 19.6245 - learning_rate: 1.0000e-04
# Epoch 20/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:20 137ms/step - BinaryAccuracy: 0.7188 - loss: 90.5945
# Epoch 20: saving model to /kaggle/working/Weights/EffiNet-bhsig260-020.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.7353 - loss: 85.2706 - val_BinaryAccuracy: 0.6839 - val_loss: 19.7871 - learning_rate: 1.0000e-04
# Epoch 21/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.6765 - loss: 95.6687
# Epoch 21: saving model to /kaggle/working/Weights/EffiNet-bhsig260-021.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.6765 - loss: 95.6588 - val_BinaryAccuracy: 0.6839 - val_loss: 12.2260 - learning_rate: 1.0000e-04
# Epoch 22/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:24 141ms/step - BinaryAccuracy: 0.7188 - loss: 56.6470
# Epoch 22: saving model to /kaggle/working/Weights/EffiNet-bhsig260-022.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.7353 - loss: 53.3180 - val_BinaryAccuracy: 0.6839 - val_loss: 12.3260 - learning_rate: 1.0000e-04
# Epoch 23/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.6738 - loss: 55.9816
# Epoch 23: saving model to /kaggle/working/Weights/EffiNet-bhsig260-023.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.6738 - loss: 55.9748 - val_BinaryAccuracy: 0.6839 - val_loss: 7.3184 - learning_rate: 1.0000e-04
# Epoch 24/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:25 143ms/step - BinaryAccuracy: 0.7812 - loss: 25.2056
# Epoch 24: saving model to /kaggle/working/Weights/EffiNet-bhsig260-024.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.7647 - loss: 25.6358 - val_BinaryAccuracy: 0.6839 - val_loss: 7.3730 - learning_rate: 1.0000e-04
# Epoch 25/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - BinaryAccuracy: 0.6733 - loss: 29.6988
# Epoch 25: saving model to /kaggle/working/Weights/EffiNet-bhsig260-025.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 175s 171ms/step - BinaryAccuracy: 0.6733 - loss: 29.6941 - val_BinaryAccuracy: 0.6839 - val_loss: 3.5449 - learning_rate: 1.0000e-04
# Epoch 26/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:24 141ms/step - BinaryAccuracy: 0.7188 - loss: 12.7056
# Epoch 26: saving model to /kaggle/working/Weights/EffiNet-bhsig260-026.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.7059 - loss: 12.7649 - val_BinaryAccuracy: 0.6839 - val_loss: 3.5986 - learning_rate: 1.0000e-04
# Epoch 27/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.6723 - loss: 13.2573
# Epoch 27: saving model to /kaggle/working/Weights/EffiNet-bhsig260-027.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.6723 - loss: 13.2547 - val_BinaryAccuracy: 0.6866 - val_loss: 1.5102 - learning_rate: 1.0000e-04
# Epoch 28/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:25 143ms/step - BinaryAccuracy: 0.6562 - loss: 6.4342
# Epoch 28: saving model to /kaggle/working/Weights/EffiNet-bhsig260-028.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.6471 - loss: 6.4487 - val_BinaryAccuracy: 0.6862 - val_loss: 1.5304 - learning_rate: 1.0000e-04
# Epoch 29/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.6702 - loss: 4.8529
# Epoch 29: saving model to /kaggle/working/Weights/EffiNet-bhsig260-029.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.6702 - loss: 4.8518 - val_BinaryAccuracy: 0.7403 - val_loss: 0.5038 - learning_rate: 1.0000e-04
# Epoch 30/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:25 142ms/step - BinaryAccuracy: 0.7188 - loss: 1.4377
# Epoch 30: saving model to /kaggle/working/Weights/EffiNet-bhsig260-030.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.7353 - loss: 1.3532 - val_BinaryAccuracy: 0.7400 - val_loss: 0.5030 - learning_rate: 1.0000e-04
# Epoch 31/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.6717 - loss: 1.3781
# Epoch 31: saving model to /kaggle/working/Weights/EffiNet-bhsig260-031.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.6717 - loss: 1.3777 - val_BinaryAccuracy: 0.6720 - val_loss: 0.2443 - learning_rate: 1.0000e-04
# Epoch 32/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:25 142ms/step - BinaryAccuracy: 0.6250 - loss: 0.4054
# Epoch 32: saving model to /kaggle/working/Weights/EffiNet-bhsig260-032.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.6177 - loss: 0.4027 - val_BinaryAccuracy: 0.6782 - val_loss: 0.2448 - learning_rate: 1.0000e-04
# Epoch 33/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.6851 - loss: 0.3409
# Epoch 33: saving model to /kaggle/working/Weights/EffiNet-bhsig260-033.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.6851 - loss: 0.3408 - val_BinaryAccuracy: 0.4553 - val_loss: 0.2959 - learning_rate: 1.0000e-04
# Epoch 34/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:25 142ms/step - BinaryAccuracy: 0.6875 - loss: 0.2530
# Epoch 34: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-06.
#
# Epoch 34: saving model to /kaggle/working/Weights/EffiNet-bhsig260-034.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.6765 - loss: 0.2566 - val_BinaryAccuracy: 0.4558 - val_loss: 0.2954 - learning_rate: 1.0000e-04
# Epoch 35/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.7332 - loss: 0.2210
# Epoch 35: saving model to /kaggle/working/Weights/EffiNet-bhsig260-035.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.7332 - loss: 0.2210 - val_BinaryAccuracy: 0.4445 - val_loss: 0.3017 - learning_rate: 1.0000e-05
# Epoch 36/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:26 143ms/step - BinaryAccuracy: 0.6562 - loss: 0.3343
# Epoch 36: saving model to /kaggle/working/Weights/EffiNet-bhsig260-036.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.6765 - loss: 0.3273 - val_BinaryAccuracy: 0.4452 - val_loss: 0.3014 - learning_rate: 1.0000e-05
# Epoch 37/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.7348 - loss: 0.2158
# Epoch 37: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 37: saving model to /kaggle/working/Weights/EffiNet-bhsig260-037.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.7348 - loss: 0.2158 - val_BinaryAccuracy: 0.4386 - val_loss: 0.3051 - learning_rate: 1.0000e-05
# Epoch 38/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:21 138ms/step - BinaryAccuracy: 0.9062 - loss: 0.0884
# Epoch 38: saving model to /kaggle/working/Weights/EffiNet-bhsig260-038.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.8824 - loss: 0.0930 - val_BinaryAccuracy: 0.4408 - val_loss: 0.3037 - learning_rate: 1.0000e-06
# Epoch 39/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.7381 - loss: 0.2070
# Epoch 39: saving model to /kaggle/working/Weights/EffiNet-bhsig260-039.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.7381 - loss: 0.2070 - val_BinaryAccuracy: 0.4419 - val_loss: 0.3022 - learning_rate: 1.0000e-06
# Epoch 40/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:22 140ms/step - BinaryAccuracy: 0.7188 - loss: 0.1995
# Epoch 40: saving model to /kaggle/working/Weights/EffiNet-bhsig260-040.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.7059 - loss: 0.1985 - val_BinaryAccuracy: 0.4417 - val_loss: 0.3020 - learning_rate: 1.0000e-06
# Epoch 41/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.7396 - loss: 0.2094
# Epoch 41: saving model to /kaggle/working/Weights/EffiNet-bhsig260-041.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.7396 - loss: 0.2094 - val_BinaryAccuracy: 0.4402 - val_loss: 0.3036 - learning_rate: 1.0000e-06
# Epoch 42/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:27 145ms/step - BinaryAccuracy: 0.5000 - loss: 0.2962
# Epoch 42: saving model to /kaggle/working/Weights/EffiNet-bhsig260-042.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.5294 - loss: 0.2886 - val_BinaryAccuracy: 0.4408 - val_loss: 0.3029 - learning_rate: 1.0000e-06
# Epoch 43/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.7442 - loss: 0.2051
# Epoch 43: saving model to /kaggle/working/Weights/EffiNet-bhsig260-043.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.7442 - loss: 0.2051 - val_BinaryAccuracy: 0.4355 - val_loss: 0.3060 - learning_rate: 1.0000e-06
# Epoch 44/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:24 141ms/step - BinaryAccuracy: 0.7500 - loss: 0.2176
# Epoch 44: saving model to /kaggle/working/Weights/EffiNet-bhsig260-044.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.7647 - loss: 0.2170 - val_BinaryAccuracy: 0.4374 - val_loss: 0.3048 - learning_rate: 1.0000e-06
# Epoch 45/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.7417 - loss: 0.2064
# Epoch 45: saving model to /kaggle/working/Weights/EffiNet-bhsig260-045.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.7417 - loss: 0.2064 - val_BinaryAccuracy: 0.4366 - val_loss: 0.3056 - learning_rate: 1.0000e-06
# Epoch 46/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:26 144ms/step - BinaryAccuracy: 0.6250 - loss: 0.2485
# Epoch 46: saving model to /kaggle/working/Weights/EffiNet-bhsig260-046.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.6470 - loss: 0.2464 - val_BinaryAccuracy: 0.4388 - val_loss: 0.3042 - learning_rate: 1.0000e-06
# Epoch 47/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.7451 - loss: 0.2028
# Epoch 47: saving model to /kaggle/working/Weights/EffiNet-bhsig260-047.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.7451 - loss: 0.2028 - val_BinaryAccuracy: 0.4325 - val_loss: 0.3074 - learning_rate: 1.0000e-06
# Epoch 48/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:25 142ms/step - BinaryAccuracy: 0.6875 - loss: 0.1982
# Epoch 48: saving model to /kaggle/working/Weights/EffiNet-bhsig260-048.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.6765 - loss: 0.1974 - val_BinaryAccuracy: 0.4341 - val_loss: 0.3067 - learning_rate: 1.0000e-06
# Epoch 49/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.7462 - loss: 0.2015
# Epoch 49: saving model to /kaggle/working/Weights/EffiNet-bhsig260-049.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.7462 - loss: 0.2015 - val_BinaryAccuracy: 0.4356 - val_loss: 0.3058 - learning_rate: 1.0000e-06
# Epoch 50/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:26 143ms/step - BinaryAccuracy: 0.6562 - loss: 0.2321
# Epoch 50: saving model to /kaggle/working/Weights/EffiNet-bhsig260-050.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.6471 - loss: 0.2335 - val_BinaryAccuracy: 0.4374 - val_loss: 0.3043 - learning_rate: 1.0000e-06
# Epoch 51/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.7469 - loss: 0.2023
# Epoch 51: saving model to /kaggle/working/Weights/EffiNet-bhsig260-051.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.7469 - loss: 0.2023 - val_BinaryAccuracy: 0.4282 - val_loss: 0.3086 - learning_rate: 1.0000e-06
# Epoch 52/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:24 141ms/step - BinaryAccuracy: 0.6562 - loss: 0.1931
# Epoch 52: saving model to /kaggle/working/Weights/EffiNet-bhsig260-052.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.6765 - loss: 0.1978 - val_BinaryAccuracy: 0.4292 - val_loss: 0.3073 - learning_rate: 1.0000e-06
# Epoch 53/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.7483 - loss: 0.1992
# Epoch 53: saving model to /kaggle/working/Weights/EffiNet-bhsig260-053.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.7483 - loss: 0.1992 - val_BinaryAccuracy: 0.4326 - val_loss: 0.3051 - learning_rate: 1.0000e-06
# Epoch 54/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:26 143ms/step - BinaryAccuracy: 0.7812 - loss: 0.2266
# Epoch 54: saving model to /kaggle/working/Weights/EffiNet-bhsig260-054.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.7941 - loss: 0.2224 - val_BinaryAccuracy: 0.4353 - val_loss: 0.3035 - learning_rate: 1.0000e-06
# Epoch 55/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.7418 - loss: 0.2034
# Epoch 55: saving model to /kaggle/working/Weights/EffiNet-bhsig260-055.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 171ms/step - BinaryAccuracy: 0.7418 - loss: 0.2034 - val_BinaryAccuracy: 0.4273 - val_loss: 0.3079 - learning_rate: 1.0000e-06
# Epoch 56/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:26 143ms/step - BinaryAccuracy: 0.6875 - loss: 0.2500
# Epoch 56: saving model to /kaggle/working/Weights/EffiNet-bhsig260-056.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.7059 - loss: 0.2488 - val_BinaryAccuracy: 0.4292 - val_loss: 0.3067 - learning_rate: 1.0000e-06
# Epoch 57/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.7489 - loss: 0.1981
# Epoch 57: saving model to /kaggle/working/Weights/EffiNet-bhsig260-057.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.7489 - loss: 0.1981 - val_BinaryAccuracy: 0.4252 - val_loss: 0.3081 - learning_rate: 1.0000e-06
# Epoch 58/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:25 142ms/step - BinaryAccuracy: 0.6875 - loss: 0.2217
# Epoch 58: saving model to /kaggle/working/Weights/EffiNet-bhsig260-058.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.6765 - loss: 0.2331 - val_BinaryAccuracy: 0.4266 - val_loss: 0.3069 - learning_rate: 1.0000e-06
# Epoch 59/60
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - BinaryAccuracy: 0.7444 - loss: 0.2012
# Epoch 59: saving model to /kaggle/working/Weights/EffiNet-bhsig260-059.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 176s 172ms/step - BinaryAccuracy: 0.7444 - loss: 0.2012 - val_BinaryAccuracy: 0.4289 - val_loss: 0.3054 - learning_rate: 1.0000e-06
# Epoch 60/60
#    1/1024 ━━━━━━━━━━━━━━━━━━━━ 2:23 141ms/step - BinaryAccuracy: 0.8125 - loss: 0.1542
# Epoch 60: saving model to /kaggle/working/Weights/EffiNet-bhsig260-060.weights.h5
# 1024/1024 ━━━━━━━━━━━━━━━━━━━━ 31s 30ms/step - BinaryAccuracy: 0.7941 - loss: 0.1596 - val_BinaryAccuracy: 0.4302 - val_loss: 0.3044 - learning_rate: 1.0000e-06

# %%
print("hello")
# Out:
# hello

# %%
import pickle

# %%
with open(folder  + '/trainHistoryDict.h5', 'wb') as file_pi:
       pickle.dump(results.history, file_pi)
model.save(folder + '/BestModel.h5')
model.save(folder + '/BestModel.keras')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
history_loaded = pickle.load(open(folder + '/trainHistoryDict.h5', "rb"))

# %%
best_result = history_loaded['val_loss'].index(min(history_loaded['val_loss'])) + 1
best_result
# Out:
# 31

# %%
def display_training_curves(training, validation, title, subplot):
  ax = plt.subplot(subplot)
  ax.plot(training)
  ax.plot(validation)
  ax.set_title('model '+ title)
  ax.set_ylabel(title)
  ax.set_xlabel('epoch')
  ax.legend(['training', 'validation'])

plt.subplots(figsize=(10,10))
plt.tight_layout()
display_training_curves(history_loaded['BinaryAccuracy'], history_loaded['val_BinaryAccuracy'], 'accuracy', 211)
display_training_curves(history_loaded['loss'], history_loaded['val_loss'], 'loss', 212)
plt.savefig(folder + "loss_accuracy.svg",dpi = 1200)

# %%
best_result
# Out:
# 31

# %%
from IPython.display import FileLink
if(best_result < 10):
  model.load_weights(folder + f'/Weights/EffiNet-bhsig260-00{best_result}.weights.h5')
  tush = FileLink(folder + f'/Weights/EffiNet-bhsig260-0{best_result}.weights.h5')
else:
  model.load_weights(folder + f'/Weights/EffiNet-bhsig260-0{best_result}.weights.h5')
  tush = FileLink(folder + f'/Weights/EffiNet-bhsig260-0{best_result}.weights.h5')

print(tush)
# Out:
# /kaggle/working/Weights/EffiNet-bhsig260-031.weights.h5

# %%
y_pred_keras = model.predict([S1_test, S2_test])
# Out:
# 220/220 ━━━━━━━━━━━━━━━━━━━━ 39s 159ms/step

# %%
y_pred_keras
# Out:
# array([[0.3274401 ],
#        [0.49391285],
#        [1.3221706 ],
#        ...,
#        [1.0654554 ],
#        [0.2605556 ],
#        [0.5546975 ]], dtype=float32)

# %%
np.min(y_pred_keras),np.mean(y_pred_keras),np.max(y_pred_keras)
# Out:
# (np.float32(0.07676262), np.float32(0.6819898), np.float32(3.4867043))

# %%
def pred_threshold(distances, threshold):
    return (distances > threshold).astype(int)

# %%
from sklearn.metrics import auc
from sklearn.metrics import roc_curve
threshold_areas = {}
for i in np.arange(0.5,0.8,0.001):
  y_pred_keras_new = pred_threshold(y_pred_keras,i)
  fpr_keras, tpr_keras, thresholds_keras = roc_curve(Y_test, y_pred_keras_new)
  auc_keras = auc(fpr_keras, tpr_keras)
  threshold_areas[i] = auc_keras
  # print(i,auc_keras)
print(threshold_areas)
max_value = list(threshold_areas.values())
max_key= list(threshold_areas.keys())
threshold = max_key[max_value.index(max(max_value))]
y_pred_keras_new = pred_threshold(y_pred_keras,threshold)
fpr_keras, tpr_keras, thresholds_keras = roc_curve(Y_test, y_pred_keras_new)
auc_keras = auc(fpr_keras, tpr_keras)
print("False Positive Rate : ",fpr_keras[1],"\nTrue Positive Rate :",tpr_keras[1])
plt.figure(1)
plt.plot([0, 1], [0, 1], 'k--')
plt.plot(fpr_keras, tpr_keras, label='Keras (area = {:.3f},threshold = {:.3f})'.format(auc_keras,threshold))
# plt.plot(fpr_rf, tpr_rf, label='RF (area = {:.3f})'.format(auc_rf))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.savefig(folder + "roc.svg",dpi = 1200)
plt.show()
# Out:
# {np.float64(0.5): np.float64(0.6596569076748213), np.float64(0.501): np.float64(0.6596107063901365), np.float64(0.502): np.float64(0.6588047247457065), np.float64(0.503): np.float64(0.6588192704579383), np.float64(0.504): np.float64(0.6588774533068651), np.float64(0.505): np.float64(0.6580423802379717), np.float64(0.506): np.float64(0.6574597125729966), np.float64(0.507): np.float64(0.6569523376171699), np.float64(0.508): np.float64(0.6560274261268964), np.float64(0.509): np.float64(0.6559957705544434), np.float64(0.51): np.float64(0.6547722523755666), np.float64(0.511): np.float64(0.6534152586386146), np.float64(0.512): np.float64(0.6529078836827878), np.float64(0.513): np.float64(0.6523397617300446), np.float64(0.514): np.float64(0.6515046886611511), np.float64(0.515): np.float64(0.6512351733970112), np.float64(0.516): np.float64(0.6492518748583891), np.float64(0.517): np.float64(0.6485357316353391), np.float64(0.518): np.float64(0.6476108201450654), np.float64(0.519): np.float64(0.6473267591686939), np.float64(0.52): np.float64(0.6460886952775853), np.float64(0.521): np.float64(0.6451492380750801), np.float64(0.522): np.float64(0.6443287107184184), np.float64(0.523): np.float64(0.6436271132075999), np.float64(0.524): np.float64(0.6431342839640048), np.float64(0.525): np.float64(0.6422093724737314), np.float64(0.526): np.float64(0.6412699152712262), np.float64(0.527): np.float64(0.6413280981201532), np.float64(0.528): np.float64(0.6407308847429465), np.float64(0.529): np.float64(0.6403715310574267), np.float64(0.53): np.float64(0.6397597719679883), np.float64(0.531): np.float64(0.6395048024160802), np.float64(0.532): np.float64(0.6390872658816333), np.float64(0.533): np.float64(0.6380870616822116), np.float64(0.534): np.float64(0.6375942324386166), np.float64(0.535): np.float64(0.6368780892155665), np.float64(0.536): np.float64(0.6361619459925164), np.float64(0.537): np.float64(0.6353414186358546), np.float64(0.538): np.float64(0.6351617417930947), np.float64(0.539): np.float64(0.6349213179534182), np.float64(0.54): np.float64(0.6342950131517481), np.float64(0.541): np.float64(0.6336832540623096), np.float64(0.542): np.float64(0.6339938423151552), np.float64(0.543): np.float64(0.6337097813387836), np.float64(0.544): np.float64(0.6334402660746438), np.float64(0.545): np.float64(0.6326488301424454), np.float64(0.546): np.float64(0.6320516167652387), np.float64(0.547): np.float64(0.6317530100766354), np.float64(0.548): np.float64(0.6316777173674871), np.float64(0.549): np.float64(0.6315125862369589), np.float64(0.55): np.float64(0.6310052112811322), np.float64(0.551): np.float64(0.6298569858114037), np.float64(0.552): np.float64(0.6290219127425101), np.float64(0.553): np.float64(0.6278882329850133), np.float64(0.554): np.float64(0.6269778672069716), np.float64(0.555): np.float64(0.6269171202100551), np.float64(0.556): np.float64(0.6266185135214517), np.float64(0.557): np.float64(0.6262155226992367), np.float64(0.558): np.float64(0.6251716813631197), np.float64(0.559): np.float64(0.6245599222736814), np.float64(0.56): np.float64(0.6243049527217732), np.float64(0.561): np.float64(0.6239310533240215), np.float64(0.562): np.float64(0.6232149101009715), np.float64(0.5630000000000001): np.float64(0.6227366265696083), np.float64(0.5640000000000001): np.float64(0.6223336357473932), np.float64(0.5650000000000001): np.float64(0.6215421998151949), np.float64(0.5660000000000001): np.float64(0.6210348248593681), np.float64(0.5670000000000001): np.float64(0.6206318340371532), np.float64(0.5680000000000001): np.float64(0.6200200749477147), np.float64(0.5690000000000001): np.float64(0.6195126999918878), np.float64(0.5700000000000001): np.float64(0.6187067183474578), np.float64(0.5710000000000001): np.float64(0.6177963525694161), np.float64(0.5720000000000001): np.float64(0.6172889776135894), np.float64(0.5730000000000001): np.float64(0.6161698435683243), np.float64(0.5740000000000001): np.float64(0.6155871759033493), np.float64(0.5750000000000 ...
# False Positive Rate :  0.3925859758820902
# True Positive Rate : 0.7118997912317327

# %%
ConfusionMatrixDisplay(confusion_matrix(Y_test,y_pred_keras_new)).plot()
plt.savefig(folder + "confusionmatrix.svg",dpi = 1200)
plt.show()

# %%
i = 0
test_gen = ([S1_test[i],S2_test[i]],Y_test[i])
(img1, img2), label = test_gen
result = model([np.expand_dims(a = img1,axis = 0), np.expand_dims(a = img2,axis = 0)])

# %%
result.numpy()[0][0]
# Out:
# np.float32(0.6254961)

# %%
def predict_score(i = 0):
    '''Predict distance score and classify test images as Genuine or Forged'''
    test_gen = ([S1_test[i],S2_test[i]],Y_test[i])
    (img1, img2), label = test_gen

    fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 10))
    ax1.imshow(np.squeeze(img1), cmap='gray')
    ax2.imshow(np.squeeze(img2), cmap='gray')
    ax1.set_title('Genuine')
    if label == 0:
        ax2.set_title('Genuine')
    else:
        ax2.set_title('Forged')
    ax1.axis('off')
    ax2.axis('off')
    plt.show()
    result = model([np.expand_dims(a = img1,axis = 0), np.expand_dims(a = img2,axis = 0)])
    diff = result.numpy()[0][0]
    print("Difference Score = ", diff)
    if diff >= threshold:
        print("Its a Forged Signature")
    else:
        print("Its a Genuine Signature")

# %%
def test_accuracy():
    '''Predict distance score and classify test images as Genuine or Forged'''
    predicted_labels = []
    # y_pred_keras_new
    for i in range(len(S1_test)):
      test_gen = ([S1_test[i],S2_test[i]],Y_test[i])
      (img1, img2), label = test_gen
      if(label == y_pred_keras_new[i]):
        predicted_labels.append(True) # append True for correct value else false
      else:
        predicted_labels.append(False)
    correct_prediction = predicted_labels.count(True)
    return (correct_prediction/len(S1_test))*100,predicted_labels

# %%
with tf.device('/device:GPU:0'):
     test_acc,predicted_labels = test_accuracy()

# %%
test_acc
# Out:
# 67.8617157490397

# %%
predicted_labels.count(True)/len(predicted_labels)*100
# Out:
# 67.8617157490397

# %%
predicted_labels.count(False)
# Out:
# 2259

# %%
predict_score(0)
# Out:
# Difference Score =  0.51944
# Its a Forged Signature

# %%
predict_score(1)
# Out:
# Difference Score =  0.5430468
# Its a Forged Signature

# %%
predict_score(2)
# Out:
# Difference Score =  1.2926964
# Its a Forged Signature

# %%
predict_score(10)
# Out:
# Difference Score =  0.9354548
# Its a Forged Signature

# %%
predict_score(11)
# Out:
# Difference Score =  0.4330829
# Its a Genuine Signature

# %%
predict_score(13)
# Out:
# Difference Score =  0.56666994
# Its a Forged Signature

# %%
predict_score(8)
# Out:
# Difference Score =  1.4017025
# Its a Forged Signature

# %%
predict_score(19)
# Out:
# Difference Score =  1.1725622
# Its a Forged Signature

# %%
predict_score(20)
# Out:
# Difference Score =  1.3281443
# Its a Forged Signature
